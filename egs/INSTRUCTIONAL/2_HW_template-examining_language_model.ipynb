# %% [markdown]
# # 2.HW: Examining language models in more detail

# %% [markdown]
# ## Task
#
# Using The `Comparing probabilities` section of `2_2-examining_language_model.ipynb` as an example, develop a case study that analyzes some aspect of language modeling.
#
# ### Suggestions
#
# - impact of `4-gram` v. `3-gram` v. `2-gram`
# - impact of `start` and `stop` symbols

# %% [markdown]
# ## Procedure
#
#   1. Copy this notebook and rename it `2_HW_[your-last-name]-examining_language_model.ipynb`.  This is **vital** so as not to create `git conflict`s!
#   2. Add your case study to the section below
#   3. **Preferred** Save your finished `notebook` as `PDF`: `File` - `Download As` - `PDF`.  **Note** This will require `pandoc`.  Installation instructions are [here](http://pandoc.org/installing.html)
#   3. **Less Preferred** Save your finished `notebook` as `html`: `File` - `Download As` - `HTML`.
#   4. Post your file to ________

# %% [markdown]
# ## Case Study: ???
